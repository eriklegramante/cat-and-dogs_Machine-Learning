# %%
import tensorflow as tf
import pandas as pd 
import os

# %%
BASE_DIR = '/home/legramante/Documentos/catandogs/cats_and_dogs'
TRAIN_DIR = os.path.join(BASE_DIR, 'train')
VALID_DIR = os.path.join(BASE_DIR, 'val')
TEST_DIR = os.path.join(BASE_DIR, 'test')

IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 10

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train_ds = tf.keras.utils.image_dataset_from_directory(
#       2     TRAIN_DIR,
#       3     image_size=IMAGE_SIZE,
#       4     batch_size=BATCH_SIZE,
#       5     label_mode='binary'
#       6 )
#
# File ~/Documentos/catandogs/venv/lib/python3.13/site-packages/keras/src/utils/image_dataset_utils.py:265, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     263 if seed is None:
#     264     seed = np.random.randint(1e6)
# --> 265 image_paths, labels, class_names = dataset_utils.index_directory(
#     266     directory,
#     267     labels,
#     268     formats=ALLOWLIST_FORMATS,
#     269     class_names=class_names,
#     270     shuffle=shuffle,
#     271     seed=seed,
#     272     follow_links=follow_links,
#     273     verbose=verbose,
#     274 )
#     276 if label_mode == "binary" and len(class_names) != 2:
#     277     raise ValueError(
#     278         'When passing `label_mode="binary"`, there must be exactly 2 '
#     279         f"class_names. Received: class_names={class_names}"
#     280     )
#
# File ~/Documentos/catandogs/venv/lib/python3.13/site-packages/keras/src/utils/dataset_utils.py:743, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links, verbose)
#     741 if labels == "inferred":
#     742     subdirs = []
# --> 743     for subdir in sorted(os_module.listdir(directory)):
#     744         if path_module.isdir(path_module.join(directory, subdir)):
#     745             if not subdir.startswith("."):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../cat_and_dogs/train'
